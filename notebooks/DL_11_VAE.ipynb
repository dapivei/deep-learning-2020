# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.utils import plot_model

# %%
# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = np.round(x_train.astype('float32') / 255.)
x_test  = np.round(x_test.astype('float32')  / 255.)

x_train = x_train.reshape((x_train.shape[0], -1))
x_test  = x_test.reshape((x_test.shape[0], -1))

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
# Show a few examples
plt.figure(figsize=(20, 4))
for i in range(10):
    ax = plt.subplot(1, 10, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Hyper-parameters
batch_size = 50
latent_len = 32

# %%
# AUX function -- Sampler
def sample_z(args):
    mean, var = args
    batch_size = tf.shape(mean)[0]
    eps = tf.random.normal(shape=(batch_size, latent_len))
    return mean + tf.exp(var) * eps

# %%
# Q(z|x) -- Define encoder
in_layer = Input(shape=(784,), name='INPUT')
h_q = Dense(512, activation='relu', name='H_Q')(in_layer)

mu = Dense(latent_len, activation='linear', name='MU')(h_q)
log_sigma = Dense(latent_len, activation='linear', name='SIGMA')(h_q)

# %%
# z ~ Q(z|X) -- Latent sample
z = Lambda(sample_z, name='Z')([mu, log_sigma])

# %%
# final encoder
encoder = Model(in_layer, z, name='ENCODER')
encoder.summary()
# Out:
# Model: "ENCODER"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# INPUT (InputLayer)              [(None, 784)]        0
# __________________________________________________________________________________________________
# H_Q (Dense)                     (None, 512)          401920      INPUT[0][0]
# __________________________________________________________________________________________________
# MU (Dense)                      (None, 32)           16416       H_Q[0][0]
# __________________________________________________________________________________________________
# SIGMA (Dense)                   (None, 32)           16416       H_Q[0][0]
# __________________________________________________________________________________________________
# Z (Lambda)                      (None, 32)           0           MU[0][0]
#                                                                  SIGMA[0][0]
# ==================================================================================================
# Total params: 434,752
# Trainable params: 434,752
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Plot model
plot_model(encoder, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True, dpi=96)

# %%
# P(x|z) -- Define decoder
decode_in_layer = Input(shape=(latent_len,), name='IN_DECOD')
decode_hidden = Dense(512, activation='relu', name='H_P')(decode_in_layer)
decode_out_layer = Dense(784, activation='sigmoid', name='OUT')(decode_hidden)

decoder = Model(decode_in_layer, decode_out_layer, name='DECODER')
decoder.summary()
# Out:
# Model: "DECODER"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# IN_DECOD (InputLayer)        [(None, 32)]              0
# _________________________________________________________________
# H_P (Dense)                  (None, 512)               16896
# _________________________________________________________________
# OUT (Dense)                  (None, 784)               402192
# =================================================================
# Total params: 419,088
# Trainable params: 419,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot model
plot_model(decoder, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True, dpi=96)

# %%
# Create full Variational Autoencoder
out_layer = decoder(encoder(in_layer))
vae = Model(in_layer, out_layer, name='VAE')
vae.summary()
# Out:
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# INPUT (InputLayer)           [(None, 784)]             0
# _________________________________________________________________
# ENCODER (Model)              (None, 32)                434752
# _________________________________________________________________
# DECODER (Model)              (None, 784)               419088
# =================================================================
# Total params: 853,840
# Trainable params: 853,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot model
plot_model(vae, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True, dpi=96)

# %%
# AUX -- VAE custom loss (DKL + BCE)
def vae_loss(x, x_hat):
    # E[log P(X|z)] - BCE
    reconst = binary_crossentropy(tf.keras.backend.flatten(x), tf.keras.backend.flatten(x_hat))
    # D_KL(Q(z|X) || P(z|X))
    dkl = -0.5 * tf.reduce_sum(1 + log_sigma - tf.square(mu) - tf.exp(log_sigma), axis=-1)
    return reconst + 0.00003 * dkl

# %%
# Compile and train
vae.compile(optimizer='adam', loss=vae_loss, experimental_run_tf_function=False)
history = vae.fit(x_train, x_train, epochs=50, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] -
# Epoch 33/50
# 48000/48000 [==============================] - 26s 540us/sample - loss: 0.0307 - val_loss: 0.0413
# Epoch 34/50
# 48000/48000 [==============================] - 27s 560us/sample - loss: 0.0306 - val_loss: 0.0408
# Epoch 35/50
# 48000/48000 [==============================] - 23s 484us/sample - loss: 0.0305 - val_loss: 0.0413
# Epoch 36/50
# 48000/48000 [==============================] - 26s 547us/sample - loss: 0.0304 - val_loss: 0.0414
# Epoch 37/50
# 48000/48000 [==============================] - 23s 474us/sample - loss: 0.0303 - val_loss: 0.0411
# Epoch 38/50
# 48000/48000 [==============================] - 22s 456us/sample - loss: 0.0302 - val_loss: 0.0413
# Epoch 39/50
# 48000/48000 [==============================] - 21s 435us/sample - loss: 0.0301 - val_loss: 0.0412
# Epoch 40/50
# 48000/48000 [==============================] - 21s 429us/sample - loss: 0.0300 - val_loss: 0.0413
# Epoch 41/50
# 48000/48000 [==============================] - 22s 451us/sample - loss: 0.0300 - val_loss: 0.0411
# Epoch 42/50
# 48000/48000 [==============================] - 21s 446us/sample - loss: 0.0299 - val_loss: 0.0412
# Epoch 43/50
# 48000/48000 [==============================] - 20s 421us/sample - loss: 0.0297 - val_loss: 0.0413
# Epoch 44/50
# 48000/48000 [==============================] - 21s 437us/sample - loss: 0.0297 - val_loss: 0.0416
# Epoch 45/50
# 48000/48000 [==============================] - 23s 475us/sample - loss: 0.0296 - val_loss: 0.0413
# Epoch 46/50
# 48000/48000 [==============================] - 28s 578us/sample - loss: 0.0296 - val_loss: 0.0415
# Epoch 47/50
# 48000/48000 [==============================] - 25s 521us/sample - loss: 0.0295 - val_loss: 0.0414
# Epoch 48/50
# 48000/48000 [==============================] - 25s 525us/sample - loss: 0.0294 - val_loss: 0.0414
# Epoch 49/50
# 48000/48000 [==============================] - 22s 452us/sample - loss: 0.0294 - val_loss: 0.0418
# Epoch 50/50
# 48000/48000 [==============================] - 24s 491us/sample - loss: 0.0293 - val_loss: 0.0415

# %%
# Plot distribution of latent space
x_test_encoded = encoder.predict(x_test, batch_size=100)

plt.figure(figsize=(8, 3))
plt.boxplot(x_test_encoded)
plt.xlabel('Latent space variables')
plt.ylabel('Values distribution')
plt.grid()
plt.show()

# %%
z_samples = np.random.normal(loc=0.0, scale=4., size=(10, latent_len))
x_hat_samples = decoder.predict(z_samples)

# Show a few reconstruction from random samples
plt.figure(figsize=(20, 3))
for i in range(10):
    ax = plt.subplot(1, 10, i + 1)
    plt.imshow(x_hat_samples[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
n = 20  # figure with 15x15 digits -- NO
digit_size = 28

z1 = np.linspace(-3.99, 3.99, n)
z2 = np.linspace(-3.99, 3.99, n)
z_grid = np.dstack(np.meshgrid(z1, z2))
print(z_grid.shape)

x_pred_grid = decoder.predict(z_grid.reshape(n*n, latent_len)) \
                     .reshape(n, n, digit_size, digit_size)

plt.figure(figsize=(10, 10))
plt.imshow(np.block(list(map(list, x_pred_grid))), cmap='gray')
plt.axis('off')
plt.show()

# %%
# Regular AE

# %%
# Define encoder
i = Input(shape=(784,))
h = Dense(512, activation='relu')(i)
l = Dense(32, activation='relu')(h)

enc = Model(i, l)
enc.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                16416
# =================================================================
# Total params: 418,336
# Trainable params: 418,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define decoder
i_d = Input(shape=(32,))
h_d = Dense(512, activation='relu')(i_d)
o_d = Dense(784, activation='sigmoid')(h_d)

dec = Model(i_d, o_d)
dec.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               16896
# _________________________________________________________________
# dense_19 (Dense)             (None, 784)               402192
# =================================================================
# Total params: 419,088
# Trainable params: 419,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define full AE
o = dec(enc(i))
ae = Model(i, o)
ae.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# model_11 (Model)             (None, 32)                418336
# _________________________________________________________________
# model_12 (Model)             (None, 784)               419088
# =================================================================
# Total params: 837,424
# Trainable params: 837,424
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and train
ae.compile(optimizer='adam', loss='bce')
history2 = ae.fit(x_train, x_train, epochs=50, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 15s 303us/sample - loss: 0.1176 - val_loss: 0.0769
# Epoch 2/50
# 48000/48000 [==============================] - 16s 344us/sample - loss: 0.0691 - val_loss: 0.0653
# Epoch 3/50
# 48000/48000 [==============================] - 17s 353us/sample - loss: 0.0608 - val_loss: 0.0597
# Epoch 4/50
# 48000/48000 [==============================] - 18s 379us/sample - loss: 0.0559 - val_loss: 0.0564
# Epoch 5/50
# 48000/48000 [==============================] - 18s 384us/sample - loss: 0.0527 - val_loss: 0.0540
# Epoch 6/50
# 48000/48000 [==============================] - 18s 376us/sample - loss: 0.0505 - val_loss: 0.0532
# Epoch 7/50
# 48000/48000 [==============================] - 20s 407us/sample - loss: 0.0486 - val_loss: 0.0516
# Epoch 8/50
# 48000/48000 [==============================] - 20s 409us/sample - loss: 0.0473 - val_loss: 0.0510
# Epoch 9/50
# 48000/48000 [==============================] - 21s 430us/sample - loss: 0.0460 - val_loss: 0.0505
# Epoch 10/50
# 48000/48000 [==============================] - 20s 411us/sample - loss: 0.0451 - val_loss: 0.0491
# Epoch 11/50
# 48000/48000 [==============================] - 20s 408us/sample - loss: 0.0443 - val_loss: 0.0490
# Epoch 12/50
# 48000/48000 [==============================] - 20s 411us/sample - loss: 0.0435 - val_loss: 0.0488
# Epoch 13/50
# 48000/48000 [==============================] - 22s 456us/sample - loss: 0.0429 - val_loss: 0.0480
# Epoch 14/50
# 48000/48000 [==============================] - 21s 442us/sample - loss: 0.0423 - val_loss: 0.0481
# Epoch 15/50
# 48000/48000 [==============================] - 19s 396us/sample - loss: 0.0418 - val_loss: 0.0475
# Epoch 16/50
# 48000/48000 [==============================] - 23s 474us/sample - loss: 0.0413 - val_loss: 0.0476
# Epoch 17/50
# 48000/48000 [==============================] - 24s 493us/sample - loss: 0.0409 - val_loss: 0.0474
# Epoch 18/50
# 48000/48000 [==============================] - 23s 479us/sample - loss: 0.0404 - val_loss: 0.0471
# Epoch 19/50
# 48000/48000 [==============================] - 22s 455us/sample - loss: 0.0398 - val_loss: 0.0470
# Epoch 20/50
# 48000/48000 [==============================] - 22s 468us/sample - loss: 0.0392 - val_loss: 0.0469
# Epoch 21/50
# 48000/48000 [==============================] - 21s 439us/sample - loss: 0.0388 - val_loss: 0.0463
# Epoch 22/50
# 48000/48000 [==============================] - 23s 471us/sample - loss: 0.0384 - val_loss: 0.0458
# Epoch 23/50
# 48000/48000 [==============================] - 21s 434us/sample - loss: 0.0380 - val_loss: 0.0460
# Epoch 24/50
# 48000/48000 [==============================] - 20s 421us/sample - loss: 0.0377 - val_loss: 0.0456
# Epoch 25/50
# 48000/48000 [==============================] - 21s 431us/sample - loss: 0.0375 - val_loss: 0.0456
# Epoch 26/50
# 48000/48000 [==============================] - 21s 434us/sample - loss: 0.0372 - val_loss: 0.0457
# Epoch 27/50
# 48000/48000 [==============================] - 20s 414us/sample - loss: 0.0369 - val_loss: 0.0453
# Epoch 28/50
# 48000/48000 [==============================] - 21s 432us/sample - loss: 0.0364 - val_loss: 0.0451
# Epoch 29/50
# 48000/48000 [==============================] - 20s 419us/sample - loss: 0.0361 - val_loss: 0.0452
# Epoch 30/50
# 48000/48000 [==============================] - 21s 438us/sample - loss: 0.0357 - val_loss: 0.0451
# Epoch 31/50
# 48000/48000 [==============================] - 21s 444us/sample - loss: 0.0355 - val_loss: 0.0444
# Epoch 32/50
# 48000/48000 [==============================] - 21s 432us/sample - loss: 0.0353 - val_loss: 0.0448
# Epoch 33/50
# 48000/48000 [==============================] - 20s 421us/sample - loss: 0.0350 - val_loss: 0.0447
# Epoch 34/50
# 48000/48000 [==============================] - 21s 434us/sample - loss: 0.0348 - val_loss: 0.0441
# Epoch 35/50
# 48000/48000 [==============================] - 21s 431us/sample - loss: 0.0346 - val_loss: 0.0439
# Epoch 36/50
# 48000/48000 [==============================] - 21s 429us/sample - loss: 0.0344 - val_loss: 0.0444
# Epoch 37/50
# 48000/48000 [==============================] - 20s 423us/sample - loss: 0.0342 - val_loss: 0.0445
# Epoch 38/50
# 48000/48000 [==============================] - 21s 436us/sample - loss: 0.0340 - val_loss: 0.0443
# Epoch 39/50
# 48000/48000 [==============================] - 20s 423us/sample - loss: 0.0338 - val_loss: 0.0442
# Epoch 40/50
# 48000/48000 [==============================] - 21s 444us/sample - loss: 0.0338 - val_loss: 0.0444
# Epoch 41/50
# 48000/48000 [==============================] - 22s 457us/sample - loss: 0.0336 - val_loss: 0.0445
# Epoch 42/50
# 48000/48000 [==============================] - 20s 417us/sample - loss: 0.0334 - val_loss: 0.0444
# Epoch 43/50
# 48000/48000 [==============================] - 21s 448us/sample - loss: 0.0333 - val_loss: 0.0443
# Epoch 44/50
# 48000/48000 [==============================] - 21s 440us/sample - loss: 0.0332 - val_loss: 0.0441
# Epoch 45/50
# 48000/48000 [==============================] - 20s 426us/sample - loss: 0.0331 - val_loss: 0.0442
# Epoch 46/50
# 48000/48000 [==============================] - 21s 428us/sample - loss: 0.0330 - val_loss: 0.0440
# Epoch 47/50
# 48000/48000 [==============================] - 23s 472us/sample - loss: 0.0329 - val_loss: 0.0448
# Epoch 48/50
# 48000/48000 [==============================] - 26s 550us/sample - loss: 0.0327 - val_loss: 0.0443
# Epoch 49/50
# 48000/48000 [==============================] - 23s 487us/sample - loss: 0.0327 - val_loss: 0.0445
# Epoch 50/50
# 48000/48000 [==============================] - 21s 439us/sample - loss: 0.0325 - val_loss: 0.0449

# %%
# Plot distribution of latent space
encoded2 = enc.predict(x_test, batch_size=100)
mean2 = encoded2.mean(axis=0)
std2  = encoded2.std(axis=0)

plt.figure(figsize=(8, 3))
plt.boxplot(encoded2)
plt.xlabel('Latent space variables')
plt.ylabel('Values distribution')
plt.grid()
plt.show()

# %%
z_samples = np.random.normal(loc=0.0, scale=3., size=(10, latent_len))
x_hat_samples = dec.predict(z_samples)

# Show a few reconstruction from random samples
plt.figure(figsize=(20, 3))
for i in range(10):
    ax = plt.subplot(1, 10, i + 1)
    plt.imshow(x_hat_samples[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# 2D Plots of 2D latent spaces

# %%
# Plot latent space for 2-D from "regular AE"

plt.scatter(encoded2[:, 0], encoded2[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %%
# Plot latent space for 2-D from "VAE"
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()
